# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# Load the extension (if you haven't already)
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/poc/tensorboard
